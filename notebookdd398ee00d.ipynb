# %%
# !git clone https://github.com/gvessere/Photon.git
# !pip install -q accelerate deepspeed
# Out:
# Cloning into 'Photon'...
# remote: Enumerating objects: 219, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 219 (delta 140), reused 142 (delta 63), pack-reused 0 (from 0)
# Receiving objects: 100% (219/219), 191.02 KiB | 3.54 MiB/s, done.
# Resolving deltas: 100% (140/140), done.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 20.2 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# !cd Photon; git pull
# Out:
# Already up to date.

# %%
1
# Out:
# 1

# %%
#!cd Photon; accelerate launch --num_processes 2 train_baseline_zero3.py
# !cd Photon; WANDB_API_KEY="ede5f54368d407abfa6074b787c469bed10e52cd" accelerate \
    launch --num_processes 2 --num_machines 1 --mixed_precision fp16 --dynamo_backend no \
    train_accel_zero3.py --wandb \
    --wandb_project photon \
    --batch_size 3 \
    --log_latent_stats \
    --resume "/kaggle/input/models/gvessere/dr6-20000/pytorch/default/1/photon_20000_ dr6mt8a4.pt" \
    --wandb_id dr6mt8a4
    
    #--lambda_rec 0 --lambda_ctx 0 --no_detach_conditioning
# Out:
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ...

# %%
! cd Photon; python3 test_generate.py --max_tokens 5000 --checkpoint /kaggle/working/Photon/checkpoints_photon/photon_18500.pt

# %%
import torch.nn.functional as F
import torch
from typing import List

logits: List = torch.randint(20, (10,), dtype=float)
logits_sorted = logits.sort(descending=True)[0]

# nucleus sampling looks at the cumsum of probabilities to estimate a small subset to sample from

# %%
cum_softmax

# %%
logits_sorted_exp, logits_sorted_exp_cumsum
